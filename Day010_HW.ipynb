# %% [markdown]
# # 其他工具：Grab、PyQuery
#
#
# * 利用 Grab 套件的存取 HTML 資源
# * 利用 PyQuery 套件的解析 HTML 格式

# %% [markdown]
# ## 作業目標
#
# 將之前用 requests + beatifulsoup 實作的方式，改寫成 grab + pyquery，並且比較有哪些地方不同。

# %% [markdown]
# ## requests + BeautifulSoup

# %%
import requests
import os
from bs4 import BeautifulSoup

url ="https://www.ptt.cc/bbs/AnimalForest/M.1600354919.A.5DF.html"
r = requests.get(url, cookies={'over18': '1'},stream=True)
response = r.text
soup = BeautifulSoup(response)

# %% [markdown]
# ## Grab + PyQuery

# %%
from grab import Grab
from pyquery import PyQuery as pq

g = Grab()
resp = g.go('https://www.ptt.cc/bbs/AnimalForest/M.1600354919.A.5DF.html')
resp.body
# Out:
# b'<!DOCTYPE html>\n<html>\n\t<head>\n\t\t<meta charset="utf-8">\n\t\t\n\n<meta name="viewport" content="width=device-width, initial-scale=1">\n\n<title>[\xe5\xbf\x83\xe5\xbe\x97] \xe9\x97\x9c\xe6\x96\xbc\xe9\x9b\xaa\xe5\x93\xa5\xe5\x93\xa5\xe7\x9a\x84\xe4\xba\x8c\xe4\xb8\x89\xe4\xba\x8b - \xe7\x9c\x8b\xe6\x9d\xbf AnimalForest - \xe6\x89\xb9\xe8\xb8\xa2\xe8\xb8\xa2\xe5\xaf\xa6\xe6\xa5\xad\xe5\x9d\x8a</title>\n<meta name="robots" content="all">\n<meta name="keywords" content="Ptt BBS \xe6\x89\xb9\xe8\xb8\xa2\xe8\xb8\xa2">\n<meta name="description" content="https://i.imgur.com/g3i4pMA.jpg\n\xe9\x9b\xaa\xe5\x93\xa5\xe5\x93\xa5\xe6\x98\xaf\xe5\x8b\x95\xe6\xa3\xae\xe6\x89\x80\xe6\x9c\x89NPC\xe4\xb9\x8b\xe4\xb8\xad\xe6\x88\x91\xe6\x9c\x80\xe5\x96\x9c\xe6\xad\xa1\xe7\x9a\x84\xe4\xb8\x80\xe5\x80\x8b\xe8\xa7\x92\xe8\x89\xb2\xe3\x80\x82\n\xe4\xbb\x96\xe4\xb8\x8d\xe5\x83\x8f\xe5\x85\xb6\xe4\xbb\x96NPC\n\xe5\xb0\xb1\xe5\x8f\xaa\xe6\x9c\x89\xe7\x9f\xad\xe7\x9f\xad4\xe5\xa4\xa9\xe3\x80\x82\n\xef\xbc\xbb\xe9\x9b\xaa\xe5\xad\xa3\xe6\x99\x82\xe9\x96\x93\xef\xbc\xbd\n">\n<meta property="og:site_name" content="Ptt \xe6\x89\xb9\xe8\xb8\xa2\xe8\xb8\xa2\xe5\xaf\xa6\xe6\xa5\xad\xe5\x9d\x8a">\n<meta property="og:title" content="[\xe5\xbf\x83\xe5\xbe\x97] \xe9\x97\x9c\xe6\x96\xbc\xe9\x9b\xaa\xe5\x93\xa5\xe5\x93\xa5\xe7\x9a\x84\xe4\xba\x8c\xe4\xb8\x89\xe4\xba\x8b">\n<meta property="og:description" content="https://i.imgur.com/g3i4pMA.jpg\n\xe9\x9b\xaa\xe5\x93\xa5\xe5\x93\xa5\xe6\x98\xaf\xe5\x8b\x95\xe6\xa3\xae\xe6\x89\x80\xe6\x9c\x89NPC\xe4\xb9\x8b\xe4\xb8\xad\xe6\x88\x91\xe6\x9c\x80\xe5\x96\x9c\xe6\xad\xa1\xe7\x9a\x84\xe4\xb8\x80\xe5\x80\x8b\xe8\xa7\x92\xe8\x89\xb2\xe3\x80\x82\n\xe4\xbb\x96\xe4\xb8\x8d\xe5\x83\x8f\xe5\x85\xb6\xe4\xbb\x96NPC\n\xe5\xb0\xb1\xe5\x8f\xaa\xe6\x9c\x89\xe7\x9f\xad\xe7\x9f\xad4\xe5\xa4\xa9\xe3\x80\x82\n\xef\xbc\xbb\xe9\x9b\xaa\xe5\xad\xa3\xe6\x99\x82\xe9\x96\x93\xef\xbc\xbd\n">\n<link rel="canonical" href="https://www.ptt.cc/bbs/AnimalForest/M.1600354919.A.5DF.html">\n\n<link rel="stylesheet" type="text/css" href="//images.ptt.cc/bbs/v2.27/bbs-common.css">\n<link rel="stylesheet" type="text/css" href="//images.ptt.cc/bbs/v2.27/bbs-base.css" media="screen">\n<link rel="stylesheet" type="text/css" href="//images.ptt.cc/bbs/v2.27/bbs-custom.css">\n<link rel="stylesheet" type="text/css" href="//images.ptt.cc/bbs/v2.27/pushstream.css" media="screen">\n<link rel="stylesheet" type="text/css" href="//images.ptt.cc/bbs/v2.27/bbs-print.css" media="print">\n\n\n\n\n\t</head>\n    <body>\n\t\t\n<div id="topbar-container">\n\t<div id="topbar" class="bbs-content">\n\t\t<a id="logo" href="/bbs/">\xe6\x89\xb9\xe8\xb8\xa2\xe8\xb8\xa2\xe5\xaf\xa6\xe6\xa5\xad\xe5\x9d\x8a</a>\n\t\t<span>&rsaquo;</span>\n\t\t<a class="board" href="/bbs/AnimalForest/index.html"><span class="board-label">\xe7\x9c\x8b\xe6\x9d\xbf </span>AnimalForest</a>\n\t\t<a class="right small" href="/about.html">\xe9\x97\x9c\xe6\x96\xbc\xe6\x88\x91\xe5\x80\x91</a>\n\t\t<a class="right small" href="/contact.html">\xe8\x81\xaf\xe7\xb5\xa1\xe8\xb3\x87\xe8\xa8\x8a</a>\n\t</div>\n</div>\n<div id="navigation-container">\n\t<div id="navigation" class="bbs-content">\n\t\t<a class="board" href="/bbs/AnimalForest/index.html">\xe8\xbf\x94 ...

# %%
doc = pq(resp.body)
title = doc('title')
print(type(title), title.text())
# Out:
# <class 'pyquery.pyquery.PyQuery'> [心得] 關於雪哥哥的二三事 - 看板 AnimalForest - 批踢踢實業坊

# %% [markdown]
# ---
# requests + beatifulsoup 和 grab + pyquery 皆屬於爬蟲套件
#
# requests 可搭配 beautifulsoup4 或 pyquery 做使用，兩種都可達到網頁爬蟲的效果

# %% [markdown]
# 安裝grab還需要pycurl
#
# 先在這邊 https://grablab.org/docs/usage/installation.html ，grab install
#
# 再去 https://ithelp.ithome.com.tw/articles/10190026?sc=pt 安裝pycurl
