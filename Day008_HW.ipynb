# %% [markdown]
# # 靜態網頁的資料爬蟲策略
#
#
# * 了解靜態網頁的資料爬蟲策略
# * 認識適用於靜態網頁爬蟲的相關套件工具：Request
# * 認識適用於靜態網頁爬蟲的相關套件工具：BeatifulSoup

# %% [markdown]
# ## 作業目標
#
# 利用 Request + BeatifulSoup 爬取下列兩個網站內容並解析：
#
# 1. Dcared 網址： https://www.dcard.tw/f
# 2. 知乎： https://www.zhihu.com/explore
#
# 並且回答下面問題：
#
# 1. Request 取回之後該怎麼取出資料，資料型態是什麼？
# 2. 為什麼要使用 BeatifulSoup 處理？處理後的型態是什麼？
# 3. 觀察一下知乎回來的資料好像有點怪怪的，該怎麼解決？

# %% [markdown]
# ### 1. Dcard 網址： https://www.dcard.tw/f

# %%
import requests
from bs4 import BeautifulSoup

# %%
url = 'https://www.dcard.tw/f'
headers={'user-agent': 'my-app/0.0.1'}
r = requests.get(url,headers = headers)
r.encoding = 'utf-8'
print(r.text[0:3000])
# Out:
# <!DOCTYPE html><html lang="zh-TW"><head prefix="og: http://ogp.me/ns#" itemscope="" itemType="https://schema.org/WebSite"><meta charSet="utf-8"/><meta http-equiv="X-UA-Compatible" content="IE=edge"/><meta name="apple-mobile-web-app-status-bar-style" content="default"/><meta name="application-name" content="Dcard"/><meta name="apple-itunes-app" content="app-id=951353454"/><meta name="theme-color" content="#006aa6"/><meta name="mobile-web-app-capable" content="yes"/><meta name="apple-mobile-web-app-capable" content="yes"/><meta name="supported-color-schemes" content="light"/><meta property="fb:app_id" content="211628828926493"/><meta property="fb:pages" content="178875832200695,577748865730563,1333515469994506,619122564952487,804004803032067,178024805867764"/><meta property="al:ios:app_store_id" content="951353454"/><meta property="al:ios:app_name" content="Dcard"/><meta property="al:android:package" content="com.sparkslab.dcardreader"/><meta property="al:android:app_name" content="Dca
# ...

# %%
# 美化
print(soup.prettify())
# Out:
# <!DOCTYPE html>
# <html lang="zh-TW">
#  <head itemscope="" itemtype="https://schema.org/WebSite" prefix="og: http://ogp.me/ns#">
#   <meta charset="utf-8"/>
#   <meta content="IE=edge" http-equiv="X-UA-Compatible"/>
#   <meta content="default" name="apple-mobile-web-app-status-bar-style"/>
#   <meta content="Dcard" name="application-name"/>
#   <meta content="app-id=951353454" name="apple-itunes-app"/>
#   <meta content="#006aa6" name="theme-color"/>
#   <meta content="yes" name="mobile-web-app-capable"/>
#   <meta content="yes" name="apple-mobile-web-app-capable"/>
#   <meta content="light" name="supported-color-schemes"/>
#   <meta content="211628828926493" property="fb:app_id"/>
#   <meta content="178875832200695,577748865730563,1333515469994506,619122564952487,804004803032067,178024805867764" property="fb:pages"/>
#   <meta content="951353454" property="al:ios:app_store_id"/>
#   <meta content="Dcard" property="al:ios:app_name"/>
# ...

# %%
response = r.text

# %%
soup = BeautifulSoup(response)

# %%
soup.link['href']
# Out:
# '/_next/static/manifest.json'

# %%
print('為什麼要使用 BeatifulSoup 處理？處理後的型態是什麼？ => ')

'''
Your Code Here
'''
# Out:
# 為什麼要使用 BeatifulSoup 處理？處理後的型態是什麼？ =>
# '\nYour Code Here\n'

# %% [markdown]
# ### 2. 知乎： https://www.zhihu.com/explore

# %%
url = 'https://www.zhihu.com/explore'
r = requests.get(url)
r.encoding = 'utf-8'

print(r.text[0:600])
# Out:
# <html>
# <head><title>400 Bad Request</title></head>
# <body bgcolor="white">
# <center><h1>400 Bad Request</h1></center>
# <hr><center>openresty</center>
# </body>
# </html>

# %% [markdown]
# ### 3. 觀察一下知乎回來的資料好像有點怪怪的，該怎麼解決？

# %%
import requests
url = 'https://www.zhihu.com/explore'

'''
Your Code Here
'''
r = requests.get(url)

r.encoding = 'utf-8'
print(r.text[0:600])
# Out:
# <html>
# <head><title>400 Bad Request</title></head>
# <body bgcolor="white">
# <center><h1>400 Bad Request</h1></center>
# <hr><center>openresty</center>
# </body>
# </html>

# %% [markdown]
# ---

# %%
html_doc = """
<html>
     <head>
           <title>The story</title>
     </head>
<body>
     <p class="title-class" id="title-id"><b>The Dormouse's story</b></p>
     <p class="content">
          <a href="http://example.com/link1" class="link" id="link1">A</a>
          <a href="http://example.com/link2" class="link" id="link2">B</a>
          <a href="http://example.com/link3" class="link" id="link3">C</a>
     </p>
</body>
</html>
"""

# %%
soup = BeautifulSoup(html_doc)
soup.find(id="link3")
# Out:
# <a class="link" href="http://example.com/link3" id="link3">C</a>

# %%
r = requests.get("https://www.dcard.tw/f/mood/p/234482024")

headers={'user-agent': 'my-app/0.0.1'}
r = requests.get(url,headers = headers)
response = r.text
print(response)
# Out:
# <!DOCTYPE html><html lang="zh-TW"><head prefix="og: http://ogp.me/ns#" itemscope="" itemType="https://schema.org/WebSite"><meta charSet="utf-8"/><meta http-equiv="X-UA-Compatible" content="IE=edge"/><meta name="apple-mobile-web-app-status-bar-style" content="default"/><meta name="application-name" content="Dcard"/><meta name="apple-itunes-app" content="app-id=951353454"/><meta name="theme-color" content="#006aa6"/><meta name="mobile-web-app-capable" content="yes"/><meta name="apple-mobile-web-app-capable" content="yes"/><meta name="supported-color-schemes" content="light"/><meta property="fb:app_id" content="211628828926493"/><meta property="fb:pages" content="178875832200695,577748865730563,1333515469994506,619122564952487,804004803032067,178024805867764"/><meta property="al:ios:app_store_id" content="951353454"/><meta property="al:ios:app_name" content="Dcard"/><meta property="al:android:package" content="com.sparkslab.dcardreader"/><meta property="al:android:app_name" content="Dca
# ...

# %%
soup = BeautifulSoup(response)

# %%
divs=soup.find_all('div')

# %%
divs
# Out:
# [<div id="__next"><div class="bxef95-0 slyeh"><div class="dz5d85-0 ejxNIo"><div class="dz5d85-1 QJLIQ"><a class="dqjqtp-0 hoYSgn" href="/f" title="Dcard"><img alt="Dcard" class="sc-139xjgq-0 gpsyNH" src="/_next/static/media/logo-2ef7b50901acaa284f36a0484329ec05.svg"/></a><div class="bxef95-1 iSUXUZ"><div class="dj0ioy-0 dWIKEI"><form><label class="oo2grd-0 fsbFQu"><div class="oo2grd-2 kpeJHB"><input aria-label="搜尋" class="oo2grd-4 kUcAWl dj0ioy-2 gyxJvI" placeholder="搜尋" type="search" value=""/></div></label><button class="dj0ioy-3 DpBdT" disabled="" title="搜尋" type="button"><span aria-hidden="true" class="ptn2cr-0 sc-3yt6pz-0 dj0ioy-7 Wdace" fill="#fff" focusable="false" role="img" size="20"><svg viewbox="0 0 28 28"><path d="M22.9 21.2l-4.5-4.5A7.5 7.5 0 1017 18l4.5 4.5a.5.5 0 00.8 0l.5-.5a.5.5 0 000-.8zm-10.4-3.5a5.6 5.6 0 115.6-5.6 5.6 5.6 0 01-5.6 5.6z"></path></svg></span></button></form></div></div></div><div class="dz5d85-2 ekbLjl" role="navigation"><a class="jjui6k-0 bYrMBg s
# ...

# %%
soup.find_all('div', class_="bvk29r-0 jPPEqC")
# Out:
# [<div class="bvk29r-0 jPPEqC"><div class="bvk29r-1 exUFVS"><div class="sc-1bfxmuy-0 iCJYVe"><a href="/forum/all"><div class="sc-11gkikh-0 kbdjsU"><div class="sc-1bfxmuy-1 dxukUh"><span aria-hidden="true" class="ptn2cr-0 sc-3yt6pz-0 fdUFDQ" focusable="false" role="img"><svg viewbox="0 0 24 24"><path d="M18.95 3H5.05A2.04 2.04 0 003 5.04v13.91A2.04 2.04 0 005.05 21h13.9A2.05 2.05 0 0021 18.96V5.03A2.05 2.05 0 0018.95 3zM6.68 17.73a1.64 1.64 0 111.64-1.64 1.64 1.64 0 01-1.64 1.64zm0-4.1A1.64 1.64 0 118.32 12a1.64 1.64 0 01-1.64 1.64zm0-4.08A1.64 1.64 0 118.32 7.9a1.64 1.64 0 01-1.64 1.64zm11.86 6.77a1 1 0 01-1 1h-6.59a1 1 0 01-1-1v-.46a1 1 0 011-1h6.6a1 1 0 011 1zm0-4.1a1 1 0 01-1 1h-6.59a1 1 0 01-1-1v-.45a1 1 0 011-1h6.6a1 1 0 011 1zm0-4.08a1 1 0 01-1 1h-6.59a1 1 0 01-1-1v-.46a1 1 0 011-1h6.6a1 1 0 011 1z" data-name="icon_md_forum"></path></svg></span></div><div class="gthja3-1 loGeVD">所有看板</div></div></a><a href="/forum/popular"><div class="sc-11gkikh-0 kbdjsU"><div class="sc-1bfxmuy-
# ...

# %%
a=soup.find_all('div', {"class":"sc-10tqbnq-1 TuHNc"})

# %%
a
# Out:
# [<div class="sc-10tqbnq-1 TuHNc"><div class="d4ydwz-0 gJoEdt"><div class="sc-1kb03aj-0 kBRbec"><div class="sc-1iit2li-0 sc-1iit2li-1 bXXvDc gUIFuB"><div class="sc-1iit2li-7 EQHXJ"><div class="sc-1nqrhll-0 hKpSvn"><div class="sc-1nqrhll-1 kfqjCM"><div class="pkcmwm-0 kTOvBu"><a class="pkcmwm-1 caQTgB" href="/f" size="1">全部</a><a class="pkcmwm-1 kCSJJy" href="/f?pessoal=true" size="1">追蹤</a></div></div><div class="sc-1nqrhll-2 bbzyGK"><div class="irx12-0 ippeWV"><div class="irx12-1 gAqYKR"></div><div class="irx12-4 bCxACP">文章排序依</div><div class="fdq12b-0 fNsDOn"><button class="irx12-2 hFULBQ" type="button"><span aria-hidden="true" class="ptn2cr-0 sc-3yt6pz-0 fdUFDQ" focusable="false" role="img"><svg viewbox="0 0 16 16"><path d="M7.8 13.39a2.23 2.23 0 01-2.27-2.21A2.2 2.2 0 017.51 9a5.46 5.46 0 003.25-1.82 10 10 0 01.41 2.82 3.37 3.37 0 01-3.37 3.39zM9.05.5a14.83 14.83 0 01.53 3.38 2.44 2.44 0 01-2.4 2.62 2.57 2.57 0 01-2.56-2.62v-.26a9.71 9.71 0 00-2.25 6.25 5.63 5.63 0 0011.26 0A12 12
# ...

# %%
print(soup.prettify())
# Out:
# <!DOCTYPE html>
# <html lang="zh-TW">
#  <head itemscope="" itemtype="https://schema.org/WebSite" prefix="og: http://ogp.me/ns#">
#   <meta charset="utf-8"/>
#   <meta content="IE=edge" http-equiv="X-UA-Compatible"/>
#   <meta content="default" name="apple-mobile-web-app-status-bar-style"/>
#   <meta content="Dcard" name="application-name"/>
#   <meta content="app-id=951353454" name="apple-itunes-app"/>
#   <meta content="#006aa6" name="theme-color"/>
#   <meta content="yes" name="mobile-web-app-capable"/>
#   <meta content="yes" name="apple-mobile-web-app-capable"/>
#   <meta content="light" name="supported-color-schemes"/>
#   <meta content="211628828926493" property="fb:app_id"/>
#   <meta content="178875832200695,577748865730563,1333515469994506,619122564952487,804004803032067,178024805867764" property="fb:pages"/>
#   <meta content="951353454" property="al:ios:app_store_id"/>
#   <meta content="Dcard" property="al:ios:app_name"/>
# ...
