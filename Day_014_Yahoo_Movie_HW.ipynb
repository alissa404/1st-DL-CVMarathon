# %% [markdown]
# # YAHOO電影爬蟲練習
# ## 練習爬取電影放映資訊。必須逐步獲取電影的代號、放映地區、放映日期後，再送出查詢給伺服器。

# %%
import requests
import re
from bs4 import BeautifulSoup

# %% [markdown]
# ### 先搜尋全部的電影代號(ID)資訊

# %% [markdown]
# <select id="sbox_mid" name="movie_id" class="movie_name">
#                         <option value="">請選擇片名</option>
#                                                                                     <option value="10942" data-name="特斯拉">特斯拉</option>
#                                                             <option value="10938" data-name="解密達文西">解密達文西</option>
#                                                             <option value="10937" data-name="遺落夢境">遺落夢境</option>
#                                                             <option value="10928" data-name="麻雀放浪記2020">麻雀放浪記2020</option>
#                                                             <option value="10922" data-name="交響狂人">交響狂人</option>
#                                                             <option value="10914" data-name="阿公當家">阿公當家</option>
#                                                             <option value="10902" data-name="刻在你心底的名字">刻在你心底的名字</option>
#                                                             <option value="10901" data-name="剪刀手愛德華">剪刀手愛德華</option>
#                                                             <option value="10894" data-name="森林特攻隊：大腳ㄚ家族">森林特攻隊：大腳ㄚ家族</option>
#                                                             <option value="10866" data-name="捉魂鏡">捉魂鏡</option>
#                                                             <option value="10443" data-name="急先鋒">急先鋒</option>
#                                                             <option value="10431" data-name="紫羅蘭永恆花園電影版">紫羅蘭永恆花園電影版</option>
#                                                             <option value="10947" data-name="性之劇藥">性之劇藥</option>
#                                                             <option value="10943" data-name="重啟咲良田 前篇">重啟咲良田 前篇</option>
#                                                             <option value="10930" data-name="叢林拳霸">叢林拳霸</option>
#                                                             <option value="10929" data-name="情慾對決">情慾對決</option>
#                                                             <option value="10903" data-name="殺戮荒村">殺戮荒村</option>
#                                                             <option value="10891" data-name="電影哆啦A夢：大雄的新恐龍">電影哆啦A夢：大雄的新恐龍</option>
#                                                             <option value="10882" data-name="法蒂瑪的奇蹟">法蒂瑪的奇蹟</option>
#                                                             <option value="10844" data-name="太陽之家">太陽之家</option>
#                                                             <option value="10923" data-name="少女與戰車最終章第2話">少女與戰車最終章第2話</option>
#                                                             <option value="10921" data-name="皮諾丘的奇幻旅程">皮諾丘的奇幻旅程</option>
#                                                             <option value="10913" data-name="惡之畫">惡之畫</option>
#                                                             <option value="10905" data-name="寂寞調香師">寂寞調香師</option>
#                                                             <option value="10893" data-name="名偵探奶奶">名偵探奶奶</option>
#                                                             <option value="10892" data-name="重裝救援：全境獵殺">重裝救援：全境獵殺</option>
#                                                             <option value="10889" data-name="整容液">整容液</option>
#                                                             <option value="10870" data-name="消失的情人節">消失的情人節</option>
#                                                             <option value="10862" data-name="鋼琴師">鋼琴師</option>
#                                                             <option value="10900" data-name="麥路人">麥路人</option>
#                                                             <option value="10907" data-name="中央車站：數位修復版">中央車站：數位修復版</option>
#                                                             <option value="10899" data-name="教會">教會</option>
#                                                             <option value="10888" data-name="密弒直播">密弒直播</option>
#                                                             <option value="10886" data-name="特務搞飛機">特務搞飛機</option>
#                                                             <option value="10874" data-name="蠟筆小新：激戰！塗鴉王國與差不多四勇者">蠟筆小新：激戰！塗鴉王國與差不多四勇者</option>
#                                                             <option value="10872" data-name="海霧">海霧</option>
#                                                             <option value="10776" data-name="蘿莉破壞王">蘿莉破壞王</option>
#                                                             <option value="10544" data-name="顫役輪迴">顫役輪迴</option>
#                                                             <option value="10871" data-name="我是大哥大！！劇場版">我是大哥大！！劇場版</option>
#                                                             <option value="10847" data-name="德州電鋸殺人狂前傳：皮面人">德州電鋸殺人狂前傳：皮面人</option>
#                                                             <option value="8632" data-name="花木蘭">花木蘭</option>
#                                                             <option value="10787" data-name="馗降：粽邪2">馗降：粽邪2</option>
#                                                             <option value="10876" data-name="美麗佳人歐蘭朵">美麗佳人歐蘭朵</option>
#                                                             <option value="10858" data-name="蘇州河">蘇州河</option>
#                                                             <option value="10452" data-name="變種人">變種人</option>
#                                                             <option value="10433" data-name="TENET天能">TENET天能</option>
#                                                             <option value="10837" data-name="初心">初心</option>
#                                                             <option value="10473" data-name="可不可以，你也剛好喜歡我">可不可以，你也剛好喜歡我</option>
#                                                             <option value="10823" data-name="劇場版 新幹線變形機器人—來自未來的神速ALFA-X">劇場版 新幹線變形機器人—來自未來的神速ALFA-X</option>
#                                                             <option value="10535" data-name="逃出立法院">逃出立法院</option>
#                                                             <option value="10850" data-name="天劫倒數">天劫倒數</option>
#                                                             <option value="10841" data-name="隱藏的畫家">隱藏的畫家</option>
#                                                             <option value="10780" data-name="哈囉少女">哈囉少女</option>
#                                                             <option value="10733" data-name="怪胎">怪胎</option>
#                                                             <option value="10824" data-name="雙面追緝">雙面追緝</option>
#                                                             <option value="10806" data-name="北海小英雄">北海小英雄</option>
#                                                             <option value="10245" data-name="日間演奏會散場時">日間演奏會散場時</option>
#                                                             <option value="10838" data-name="鋼鐵雨：深潛行動">鋼鐵雨：深潛行動</option>
#                                                             <option value="10822" data-name="淒厲人僧前傳">淒厲人僧前傳</option>
#                                                             <option value="10797" data-name="戀夏時光">戀夏時光</option>
#                                                             <option value="10789" data-name="不丹是教室">不丹是教室</option>
#                                                             <option value="10775" data-name="藍色恐懼：數位修復版">藍色恐懼：數位修復版</option>
#                                                             <option value="5350" data-name="打噴嚏">打噴嚏</option>
#                                                             <option value="10647" data-name="角落小夥伴電影版：魔法繪本裡的新朋友">角落小夥伴電影版：魔法繪本裡的新朋友</option>
#                                                             <option value="10755" data-name="死因無可疑">死因無可疑</option>
#                                                             <option value="10641" data-name="破處">破處</option>
#                                                             <option value="10748" data-name="萬花嬉春">萬花嬉春</option>
#                                                             <option value="10726" data-name="福島50英雄">福島50英雄</option>
#                                                             <option value="10659" data-name="玩命Online：雙槍對決">玩命Online：雙槍對決</option>
#                                                             <option value="10559" data-name="天后小助理">天后小助理</option>
#                                                             <option value="10649" data-name="敢殺就來">敢殺就來</option>
#                                                             <option value="10636" data-name="巴黎寂寞不打烊">巴黎寂寞不打烊</option>
#                                                             <option value="10505" data-name="1/2的魔法">1/2的魔法</option>
#                                                             <option value="10495" data-name="海邊走走">海邊走走</option>
#                                                             <option value="10602" data-name="陪你玩最大">陪你玩最大</option>
#                                                             <option value="10601" data-name="無聲革命">無聲革命</option>
#                                                             <option value="10068" data-name="小魔花">小魔花</option>
#                                                             <option value="10383" data-name="極地守護犬">極地守護犬</option>
#                                                             <option value="10429" data-name="巧虎電影：英雄遊樂園">巧虎電影：英雄遊樂園</option>
#                                                             <option value="10057" data-name="AI終結戰">AI終結戰</option>
#                                                             <option value="4887" data-name="一首搖滾上月球">一首搖滾上月球</option>
#                                                             <option value="3026" data-name="錢不夠用2">錢不夠用2</option>
#                                                                         </select>

# %%
# 查看目前上映那些電影，並擷取出其ID資訊
url = 'https://movies.yahoo.com.tw/'
resp = requests.get(url)
soup = BeautifulSoup(resp.text)

# <select id ='sbox_mid' name ='movie_id' class ='movie_name'>
html = soup.find("select", attrs={'name':'movie_id'})

# <option value ='10431' data-name='xxxxx'>
movie_item = html.find_all("option", attrs={'data-name':re.compile('.*')})

for p in movie_item:
    print("Movie: %s, ID: %s" % (p["data-name"], p["value"]))
# Out:
# Movie: 玉子愛情故事, ID: 10992
# Movie: 霜花店：朕的男人, ID: 10987
# Movie: 獅子山上, ID: 10985
# Movie: 地獄通話, ID: 10980
# Movie: 迷慾東京, ID: 10970
# Movie: 戀愛好好說, ID: 10964
# Movie: 綁票追殺令, ID: 10956
# Movie: 碧藍之海劇場版, ID: 10950
# Movie: 親愛的房客, ID: 10707
# Movie: 華氏11/9, ID: 9039
# Movie: 2020高雄電影節, ID: 10996
# Movie: 地下弒的秘密, ID: 10984
# Movie: 人造紀元：走進人類世, ID: 10979
# Movie: 劇場版高校艦隊, ID: 10978
# Movie: 被告, ID: 10969
# Movie: 阿比阿弟尋歌大冒險, ID: 10968
# Movie: 男人的一半還是男人, ID: 10967
# Movie: 詭憶, ID: 10960
# Movie: 浴血劍客, ID: 10957
# Movie: 奪命守門人, ID: 10952
# Movie: 藥頭大媽, ID: 10951
# Movie: 看不見的目擊者, ID: 10946
# Movie: 幻愛, ID: 10945
# Movie: 無聲, ID: 10926
# Movie: 少女與戰車最終章 第1+2話4D, ID: 10972
# Movie: 無價之保, ID: 10959
# Movie: 千年一問, ID: 10948
# Movie: 星際效應, ID: 10941
# Movie: 辛比的怪怪屋劇場版：幽靈獵人天空大進擊, ID: 10927
# Movie: 倒數反擊, ID: 10906
# Movie: 刑警沒有假期, ID: 10881
# Movie: 愛情列車長, ID: 10857
# Movie: 工作細胞特別上映版-強「菌」來襲！人體腸道大騷動！, ID: 10827
# Movie: 特斯拉, ID: 10942
# Movie: 遺落夢境, ID: 10937
# Movie: 交響狂人, ID: 10922
# ...

# %% [markdown]
# ### 指定你有興趣的電影其ID，然後查詢其放映地區資訊。

# %%
# 參考前一個步驟中擷取到的ID資訊，並指定ID
movie_id = 10431

# %%
url = 'https://movies.yahoo.com.tw/api/v1/areas_by_movie_theater'
payload = {'movie_id':str(movie_id)}

# 自行模擬一個header
headers = {
    'authority': 'movies.yahoo.com.tw',
    'method': 'GET',
    'path': '/api/v1/areas_by_movie_theater?movie_id=' + str(movie_id),
    'scheme': 'https',
    'accept': 'application/json, text/javascript, */*; q=0.01',
    'accept-encoding': 'gzip, deflate, br',
    'accept-language': 'zh-TW,zh;q=0.9,en-US;q=0.8,en;q=0.7,zh-CN;q=0.6',
    'cookie': 'rxx=9s3x2fws06.1g16irnc&v=1; _ga=GA1.3.2056742944.1551651301; GUC=AQEBAQFczFpdm0IfmwSB&s=AQAAACoo4N5D&g=XMsVBw; BX=4hkdk1decm57t&b=3&s=mr; _ga=GA1.4.2056742944.1551651301; nexagesuid=82843256dd234e8e91aa73f2062f8218; browsed_movie=; avi=eyJpdiI6Im1NeWFJRlVRWDR1endEcGRGUGJUbVE9PSIsInZhbHVlIjoickRpU3JuUytmcGl6cjF5OW0rNU9iZz09IiwibWFjIjoiY2VmY2NkNzZmM2NhNjY5YzlkOTcyNjE5OGEyMzU0NWYxOTdmMDRkMDY3OWNmMmZjOTMxYjc5MjI5N2Q5NGE5MiJ9; cmp=t=1559391030&j=0; _gid=GA1.4.779543841.1559391031; XSRF-TOKEN=%3D; m_s=; _gat=1; nexagesd=10',
    'dnt': '1',
    'mv-authorization': '21835b082e15b91a69b3851eec7b31b82ce82afb',
    'referer': 'https://movies.yahoo.com.tw/',
    'user-agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/74.0.3729.169 Safari/537.36',
    'x-requested-with': 'XMLHttpRequest',
}
    
resp = requests.get(url, params=payload, headers=headers)

# 這裡回傳的格式是JSON格式的資料，要解析JSON擷取資料
for p in resp.json():
    print('放映地區: {0}, Area_id: {1}'.format(p['title'], p['area_id']))
# Out:
# 放映地區: 台北市, Area_id: 28
# 放映地區: 新北市, Area_id: 8
# 放映地區: 桃園, Area_id: 16
# 放映地區: 新竹, Area_id: 20
# 放映地區: 苗栗, Area_id: 15
# 放映地區: 台中, Area_id: 2
# 放映地區: 嘉義, Area_id: 21
# 放映地區: 台南, Area_id: 10
# 放映地區: 高雄, Area_id: 17
# 放映地區: 屏東, Area_id: 14
# 放映地區: 宜蘭, Area_id: 11
# 放映地區: 花蓮, Area_id: 12
# 放映地區: 金門, Area_id: 24
# 放映地區: 澎湖, Area_id: 23

# %% [markdown]
# ### 指定你想要觀看的放映地區，查詢有上映電影的場次日期

# %%
# 指定放映地區
area_id = 20

# %%
# 向網站發送請求
url = 'https://movies.yahoo.com.tw/movietime_result.html'
payload = {'movie_id':str(movie_id), 'area_id':str(area_id)}
resp = requests.get(url, params=payload)

soup = BeautifulSoup(resp.text, 'lxml')
movie_date = soup.find_all("label", attrs={'for':re.compile("date_[\d]")})

# 列印播放日期
for date in movie_date:
    print("%s %s" % (date.p.string, date.h3.string))
# Out:
# 十月 25
# 十月 26
# 十月 27
# 十月 28
# 十月 29

# %% [markdown]
# ### 最後指定觀看的日期，查詢並列印出放映的電影院、放映類型(數位、3D、IMAX 3D...)、放映時間等資訊。

# %%
# 選定要觀看的日期
date = "2020-10-25"

# %%
# 向網站發送請求，獲取上映的電影院及時間資訊
url = "https://movies.yahoo.com.tw/ajax/pc/get_schedule_by_movie"
payload = {'movie_id':str(movie_id),
           'date':date,
           'area_id':str(area_id),
           'theater_id':'',
           'datetime':'',
           'movie_type_id':''}

resp = requests.get(url, params=payload)
#print(resp.json()['view'])  # 若有需要，列印出json原始碼

soup = BeautifulSoup(resp.json()['view'], 'lxml')
html = soup.find_all("ul", attrs={'data-theater_name':re.compile(".*")})
#type_ = soup.find_all("li", class_="tapR")

# %%
for name in html:
    #print('-----------------------------------------------------')   
    theater_name = name.find("li", attrs={'class':'adds'})
    print("電影院: ", theater_name.a.string)
    
    project_type = name.find_all("li", attrs={'class':'taps'})  # 定位放映類型
    time_table = name.find_all("li", attrs={'class':'time _c'})  # 定位時間表
        
    for i in range(len(project_type)):
        print("放映類型: ", project_type[i].span.get_text())  # 印出電影類型
        
        for p4 in time_table[i].find_all("input", attrs={'name':'schedule_list'}):
            print("%s" % (p4["value"]))  # 印出放映時間
# Out:
# 電影院:  新竹大遠百威秀影城
# 放映類型:  數位
# 2020-10-25 17:35:00

# %%
# 上映中電影簡介
url = 'https://movies.yahoo.com.tw/movie_intheaters.html'
resp = requests.get(url)
soup = BeautifulSoup(resp.text, 'lxml')
html_ = soup.find("div", attrs={'class':'release_box'})  # 尋找正在上映中的全部電影筆數，其所在的tag
#print("正在上映中總共: ", html.p.string)

# %%
# 先點選網頁最底部的下一頁，觀察其網址變化。然後我們把頁數當作變數傳入，用迴圈爬取。

for page_number in html_:
    url = 'https://movies.yahoo.com.tw/movie_intheaters.html'
    payload = {'page':str(page_number)}
    resp = requests.get(url, params=payload)
    resp.encoding = 'utf-8'
    soup = BeautifulSoup(resp.text, 'lxml')

    # 把電影介紹擷取出來
    movie_list = soup.find("ul", attrs={"class":"release_list"})
    movielist = movie_list.find_all("li")
    
    for p in movielist:
        print("------------------------------------------------------------------------------")
        
        # 電影名稱
        movie_name = p.find("div", attrs={"class":"release_movie_name"})
        print("電影名稱：", movie_name.a.string)    
        
        # 期待度
        expectation = p.find("div", attrs={"class":"leveltext"})
        print("期待度：", expectation.span.string)
        
        # 滿意度
        satisfaction = p.find("div", attrs={"class":"leveltext"})
        print("滿意度：", satisfaction.span.string) 
        
        # 簡介
        movie_info = p.find("div", attrs={"class":"release_text"})
        print(movie_info.span.string)
# Out:
# ------------------------------------------------------------------------------
# 電影名稱：
#                   看不見的目擊者
# 期待度： 99%
# 滿意度： 99%
#
#                   ★ 改編自韓國經典犯罪電影《盲證》，由日本新生代實力派女星吉岡里帆聯手鮮肉帥哥高杉真宙演出
# ★ 一個因意外失明的警校畢業生，卻是連環女高中生綁架案的唯一證人，她要如何指認極惡罪犯？
# ★ 少女連環分屍慘案，智慧型殘暴罪犯與看不見的前女警展開一場鬥智對決
#
# 濱中夏目（吉岡里帆 飾）在警察學校畢業典禮當晚，因過失車禍，導致弟弟死去，自己也雙目失明，她放棄成為警察的夢想，3年來，她將自己完全封閉，只有導盲犬陪伴她過日子。
#
# 某天，夏目遭遇交通事故，在現場，她聽到車中傳出少女微弱喊救命的聲音，曾在警校受過專業訓練的她，判斷車內可能是一宗綁架案。但警方並不相信她所提供視覺以外的情報，停止調查，但少女的呼救聲讓她一直揮之不去，她找到當時也同樣目擊車禍的滑板少年（高杉真宙 飾），說服他一起尋找犯人蹤跡。
#
# 他們逐漸順著線索追查到可能遭到綁架的受害人，和一位被稱為「救神」的神秘人物。木村警官與搭檔吉野（大倉孝二 飾）也開始覺得事有蹊蹺，決定出手相助，並發現了疑似遭到殺害，堆積成山的青少女斷肢屍體。木村警官發現此案與15年前一宗謀殺案之間似乎有相關之處，這時，凶手突然出現並開始跟蹤夏目，讓她身陷險境，……
#
#
# ------------------------------------------------------------------------------
# 電影名稱：
#                   藥頭大媽
# 期待度： 88%
# 滿意度： 88%
#
#                   ★ 改編自紐時百大書單暢銷小說《教母》（The Godmother）
# ★ 法國首週票房亞軍，僅次《天能》
# ★ 《她的危險遊戲》《鋼琴教師》法國傳奇影后伊莎貝雨蓓妙趣橫生新作
# ★ 《推拿》《女僕心機》金獎製片爆笑呈獻
# ★ 50%條子＋50%毒販＝這批雨蓓100%純啦！
#
# ...
